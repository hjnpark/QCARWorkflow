# %%
from QCARWorkflow.qcaw import Workflow, User, Dataset

client = User(user = "User1", password = "1234").server()

client.list_collections() #This will show two example dataset
# Out:
# Client is ready
#                                tagline
# collection          name
# OptimizationDataset C6H6          None
#                     C6H6_2        None
#                     H2O_proton    None
#                     HCN           None
#                     reaction1     None
#                     reaction2     None
#                     reaction5     None
#                     reaction6     None
#                     reaction7     None

# %%
#Making dataset for optimizing "HCN.xyz".
ds = Dataset("HCN", ds_type = "OptimizationDataset", client=client).setting("make") # Creating an OptimizationData set named 'test'.
wf = Workflow(ds = ds, client = client, spec_name = "HCN", initial = "HCN.xyz") # Workflow class
wf.optimization(method = 'b3lyp', basis ='def2-svpd', subsample = 1, compute = True) # optimization function
ds.status(collapse = False)
# Out:
# Calculations in 'HCN' with 'HCN' specification have been submitted. Run the QCFractal manager to carry the calculations.
#              HCN
# HCN_0   COMPLETE
# HCN_1   COMPLETE
# HCN_2   COMPLETE
# HCN_3   COMPLETE
# HCN_4   COMPLETE
# HCN_5   COMPLETE
# HCN_6   COMPLETE
# HCN_7   COMPLETE
# HCN_8   COMPLETE
# HCN_9   COMPLETE
# HCN_10  COMPLETE
# HCN_11  COMPLETE
# HCN_12  COMPLETE
# HCN_13  COMPLETE
# HCN_14  COMPLETE
# HCN_15  COMPLETE
# HCN_16  COMPLETE
# HCN_17  COMPLETE
# HCN_18  COMPLETE
# HCN_19  COMPLETE
# HCN_20  COMPLETE
# HCN_21  COMPLETE

# %%
# Making another dataset for "H2O_proton.xyz".
ds_2 = Dataset("H2O_proton", ds_type = "OptimizationDataset", client=client).setting("make")
Workflow(ds = ds_2, client = client, spec_name = "H2O_proton", initial = "H2O_proton.xyz").optimization(method = 'b3lyp', basis = 'def2-svpd', subsample = 20, compute = True)
ds_2.status(collapse = False)

#Now the optimization calculations are ready. Submit the QCFractal manager to a computing resource to run calculations.
# Out:
# Calculations in 'H2O_proton' with 'H2O_proton' specification have been submitted. Run the QCFractal manager to carry the calculations.
#                H2O_proton
# H2O_proton_0     COMPLETE
# H2O_proton_20    COMPLETE
# H2O_proton_40    COMPLETE
# H2O_proton_60    COMPLETE
# H2O_proton_80    COMPLETE
# H2O_proton_100   COMPLETE
# H2O_proton_120   COMPLETE
# H2O_proton_140   COMPLETE
# H2O_proton_160   COMPLETE
# H2O_proton_180   COMPLETE
# H2O_proton_200   COMPLETE
# H2O_proton_220   COMPLETE
# H2O_proton_240   COMPLETE
# H2O_proton_260   COMPLETE
# H2O_proton_280   COMPLETE
# H2O_proton_300   COMPLETE
# H2O_proton_319   COMPLETE
