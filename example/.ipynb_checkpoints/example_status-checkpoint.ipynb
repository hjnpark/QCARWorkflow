# %%
from QCARWorkflow.qcaw import Workflow, User, Dataset

client = User(user = "User1", password = "1234").server()
# Out:
# Client is ready

# %%
print("The list of dataset\n", client.list_collections()) # This will print all the dataset the User1 has.

ds = Dataset("test", ds_type = "OptimizationDataset", client=client).setting("load") # Loading the dataset.
ds.status(collapse = False)
# Out:
# The list of dataset
#                            tagline
# collection          name
# OptimizationDataset test     None
#                     test2    None
# 'test' dataset has been loaded.
#        spec_test
# HCN_0   COMPLETE
# HCN_1   COMPLETE
# HCN_2   COMPLETE
# HCN_3   COMPLETE
# HCN_4   COMPLETE
# HCN_5   COMPLETE
# HCN_6   COMPLETE
# HCN_7   COMPLETE
# HCN_8   COMPLETE
# HCN_9   COMPLETE
# HCN_10  COMPLETE
# HCN_11  COMPLETE
# HCN_12  COMPLETE
# HCN_13  COMPLETE
# HCN_14  COMPLETE
# HCN_15  COMPLETE
# HCN_16  COMPLETE
# HCN_17  COMPLETE
# HCN_18  COMPLETE
# HCN_19  COMPLETE
# HCN_20  COMPLETE
# HCN_21  COMPLETE

# %%
# Another dataset
ds_2 = Dataset("test2", ds_type = "OptimizationDataset", client=client).setting("load")
ds_2.status(collapse = False)
# Out:
# 'test2' dataset has been loaded.
#                spec_test2
# H2O_proton_0     COMPLETE
# H2O_proton_20    COMPLETE
# H2O_proton_40    COMPLETE
# H2O_proton_60    COMPLETE
# H2O_proton_80    COMPLETE
# H2O_proton_100   COMPLETE
# H2O_proton_120   COMPLETE
# H2O_proton_140   COMPLETE
# H2O_proton_160   COMPLETE
# H2O_proton_180   COMPLETE
# H2O_proton_200   COMPLETE
# H2O_proton_220   COMPLETE
# H2O_proton_240   COMPLETE
# H2O_proton_260   COMPLETE
# H2O_proton_280   COMPLETE
# H2O_proton_300   COMPLETE
# H2O_proton_319   COMPLETE
